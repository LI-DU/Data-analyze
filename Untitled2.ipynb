# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
plt.rcParams['font.sans-serif']=['SimHei']                           # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False                             # 用来正常显示负号

# %%
df = pd.read_csv('D:/qs_charge_order01.txt',encoding = 'utf-8',sep = '\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157000 entries, 0 to 156999
# Data columns (total 13 columns):
# owner_id             41637 non-null float64
# station_id           157000 non-null object
# charge_total_fee     157000 non-null float64
# charge_type          157000 non-null int64
# pay_type             157000 non-null int64
# order_state          157000 non-null int64
# charge_energy        157000 non-null float64
# charge_limit         157000 non-null float64
# charge_mode          157000 non-null int64
# charge_start_time    156831 non-null object
# charge_end_time      156831 non-null object
# create_time          157000 non-null object
# update_time          156823 non-null object
# dtypes: float64(4), int64(4), object(5)
# memory usage: 15.6+ MB

# %%
df.describe()
# Out:
#            owner_id  charge_total_fee  charge_type  pay_type    order_state  \
# count  41637.000000     157000.000000     157000.0  157000.0  157000.000000
# mean    1346.046497         34.937770          2.0       1.0      40.988287
# std     3083.701410         41.028012          0.0       0.0       0.358123
# min        0.000000          0.000000          2.0       1.0      30.000000
# 25%      104.000000         14.210000          2.0       1.0      41.000000
# 50%      104.000000         22.880000          2.0       1.0      41.000000
# 75%      545.000000         40.040000          2.0       1.0      41.000000
# max    15988.000000        488.860000          2.0       1.0      41.000000
#
#        charge_energy   charge_limit    charge_mode
# count  157000.000000  157000.000000  157000.000000
# mean       24.176942       6.401482       0.000076
# std        23.252684      24.611309       0.015142
# min         0.000000       0.000000       0.000000
# ...

# %%
df.head()
# Out:
#    owner_id           station_id  charge_total_fee  charge_type  pay_type  \
# 0       0.0                                   9.66            2         1
# 1       0.0                                  66.97            2         1
# 2   15988.0  2690524855515910000             59.22            2         1
# 3       0.0                                   0.27            2         1
# 4       0.0                                  44.83            2         1
#
#    order_state  charge_energy  charge_limit  charge_mode   charge_start_time  \
# 0           41           9.73          9.66            0   0/1/2000 00:00:16
# 1           41          66.97         66.97            0   0/1/2000 00:00:51
# 2           41          62.34         59.22            0  23/2/2000 00:01:04
# 3           41           0.27          0.27            0   0/1/2000 00:01:06
# 4           41          47.19         44.83            0   0/1/2000 00:01:19
#
# ...

# %%
df['charge_total_fee'].max()
# Out:
# 488.86

# %%
create_time = df['create_time'].head(50)

# %%
import time
import datetime

# %%
df['create_time'] = pd.to_datetime(df['create_time'])
df['update_time'] = pd.to_datetime(df['update_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157000 entries, 0 to 156999
# Data columns (total 13 columns):
# owner_id             41637 non-null float64
# station_id           157000 non-null object
# charge_total_fee     157000 non-null float64
# charge_type          157000 non-null int64
# pay_type             157000 non-null int64
# order_state          157000 non-null int64
# charge_energy        157000 non-null float64
# charge_limit         157000 non-null float64
# charge_mode          157000 non-null int64
# charge_start_time    156831 non-null object
# charge_end_time      156831 non-null object
# create_time          157000 non-null datetime64[ns]
# update_time          156823 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(4), object(3)
# memory usage: 15.6+ MB

# %%
df = df.drop('charge_start_time',axis=1)

# %%
df = df.drop('charge_end_time',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157000 entries, 0 to 156999
# Data columns (total 11 columns):
# owner_id            41637 non-null float64
# station_id          157000 non-null object
# charge_total_fee    157000 non-null float64
# charge_type         157000 non-null int64
# pay_type            157000 non-null int64
# order_state         157000 non-null int64
# charge_energy       157000 non-null float64
# charge_limit        157000 non-null float64
# charge_mode         157000 non-null int64
# create_time         157000 non-null datetime64[ns]
# update_time         156823 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(4), object(1)
# memory usage: 13.2+ MB

# %%
df['create_time'].head()
# Out:
# 0   2019-01-22 18:58:50
# 1   2019-03-14 21:12:28
# 2   2019-02-23 18:12:17
# 3   2019-01-25 16:35:10
# 4   2019-09-02 01:12:19
# Name: create_time, dtype: datetime64[ns]

# %%
#将日期和时间（2019-09-02 01:12:19）在一起的一列数据转为只有日期列
df['create_time_d'] = df['create_time'].dt.date
df['create_time_t'] = df['create_time'].dt.time
df['update_time_t'] = df['update_time'].dt.time

# %%
df = df.drop('create_time01',axis=1)

# %%
from matplotlib.dates import DateFormatter, drange

# %%
hours = df['create_time_t'].tail(1000)
print(type(hours))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.to_csv('D:/charge_order_new.csv')

# %%
plt.hist(df['create_time_t'].tail(100),bins = 20);

# %%
plt.rcParams['font.sans-serif']=['SimHei']                           # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False                             # 用来正常显示负号

# %%
df.head(3)
# Out:
#    owner_id           station_id  charge_total_fee  charge_type  pay_type  \
# 0       0.0                                   9.66            2         1
# 1       0.0                                  66.97            2         1
# 2   15988.0  2690524855515910000             59.22            2         1
#
#    order_state  charge_energy  charge_limit  charge_mode         create_time  \
# 0           41           9.73          9.66            0 2019-01-22 18:58:50
# 1           41          66.97         66.97            0 2019-03-14 21:12:28
# 2           41          62.34         59.22            0 2019-02-23 18:12:17
#
#           update_time create_time_t update_time_t create_time_d
# 0 2019-01-22 18:58:50      18:58:50      18:58:50    2019-01-22
# 1 2019-03-14 21:12:27      21:12:28      21:12:27    2019-03-14
# 2 2019-02-23 18:12:17      18:12:17      18:12:17    2019-02-23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157000 entries, 0 to 156999
# Data columns (total 14 columns):
# owner_id            41637 non-null float64
# station_id          157000 non-null object
# charge_total_fee    157000 non-null float64
# charge_type         157000 non-null int64
# pay_type            157000 non-null int64
# order_state         157000 non-null int64
# charge_energy       157000 non-null float64
# charge_limit        157000 non-null float64
# charge_mode         157000 non-null int64
# create_time         157000 non-null datetime64[ns]
# update_time         156823 non-null datetime64[ns]
# create_time_t       157000 non-null object
# update_time_t       156823 non-null object
# create_time_d       157000 non-null object
# dtypes: datetime64[ns](2), float64(4), int64(4), object(4)
# memory usage: 16.8+ MB

# %%
df['charge_total_fee'].describe()
# Out:
# count    157000.000000
# mean         34.937770
# std          41.028012
# min           0.000000
# 25%          14.210000
# 50%          22.880000
# 75%          40.040000
# max         488.860000
# Name: charge_total_fee, dtype: float64

# %%
df['charge_energy'].describe()
# Out:
# count    157000.000000
# mean         24.176942
# std          23.252684
# min           0.000000
# 25%          12.237500
# 50%          18.030000
# 75%          29.740000
# max         322.530000
# Name: charge_energy, dtype: float64

# %%
df01 = pd.read_csv('D:/Work-Files/Data/充电订单-qs_charge_order数据/201901qs_charge_order.csv',encoding = 'utf-8')

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269665 entries, 0 to 269664
# Data columns (total 13 columns):
# owner_id             219760 non-null float64
# station_id           269665 non-null object
# charge_total_fee     269665 non-null float64
# charge_type          269665 non-null int64
# pay_type             269665 non-null int64
# order_state          269665 non-null int64
# charge_energy        269665 non-null float64
# charge_limit         269665 non-null float64
# charge_mode          269665 non-null int64
# charge_start_time    268412 non-null object
# charge_end_time      268409 non-null object
# create_time          269665 non-null object
# update_time          269060 non-null object
# dtypes: float64(4), int64(4), object(5)
# memory usage: 26.7+ MB

# %%
df01.head()
# Out:
#    owner_id           station_id  charge_total_fee  charge_type  pay_type  \
# 0    1895.0  3406694328833234077             52.73            7         9
# 1       0.0                                 123.78            4         1
# 2    8221.0  3977393150786253008              0.04            2         1
# 3     545.0  4070794765468792359            137.26            4         1
# 4     545.0  4070794765468792359            205.92            4         1
#
#    order_state  charge_energy  charge_limit  charge_mode    charge_start_time  \
# 0           41          52.73         52.73            0  31/12/2018 23:12:25
# 1           41          61.89          0.00            0    1/1/2019 00:00:11
# 2           41           0.07          0.04            0  31/12/2018 23:37:16
# 3           41          68.63          0.00            0    1/1/2019 00:00:33
# 4           41         102.96          0.00            0    1/1/2019 00:00:35
#
# ...

# %%
df01.tail()
# Out:
#         owner_id           station_id  charge_total_fee  charge_type  \
# 269660    1895.0  3406694328833234077             66.60            7
# 269661   16365.0  3403180229055990650             47.83            7
# 269662     752.0  4087405081109651454             21.83            2
# 269663    1895.0  3406694328833234077             50.42            7
# 269664     545.0  4070794765468792359              6.12            4
#
#         pay_type  order_state  charge_energy  charge_limit  charge_mode  \
# 269660         9           41          66.60         66.60            0
# 269661         9           41          43.94         47.83            0
# 269662         1           41          21.88          0.00            0
# 269663         9           41          50.42         50.42            0
# 269664         1           41           3.06          0.00            0
#
#          charge_start_time     charge_end_time         create_time  \
# ...

# %%
df01.describe()
# Out:
#            owner_id  charge_total_fee    charge_type       pay_type  \
# count  219760.00000     269665.000000  269665.000000  269665.000000
# mean     3908.98062         39.622017       3.066935       2.533414
# std      5138.87633         46.641771       1.868452       3.184442
# min         0.00000          0.000000       1.000000       1.000000
# 25%       350.00000         13.660000       2.000000       1.000000
# 50%      1277.00000         30.190000       2.000000       1.000000
# 75%      5844.00000         55.300000       4.000000       1.000000
# max     16365.00000       9257.570000       7.000000      10.000000
#
#          order_state  charge_energy   charge_limit    charge_mode
# count  269665.000000  269665.000000  269665.000000  269665.000000
# mean       40.959223      36.787125    2518.291521       0.006137
# std         0.617611      37.389952   15354.241512       0.111005
# min        12.000000       0.000000       0.000000       0.000000
# ...

# %%
df01['create_time'] = pd.to_datetime(df01['create_time'])

# %%
df01['create_time_t'] = df01['create_time'].dt.time

# %%
df01 = df01.drop('create_time',axis=1)

# %%
df01 = df01.drop('update_time',axis=1)

# %%
df01.head()
# Out:
#    owner_id           station_id  charge_total_fee  charge_type  pay_type  \
# 0    1895.0  3406694328833234077             52.73            7         9
# 1       0.0                                 123.78            4         1
# 2    8221.0  3977393150786253008              0.04            2         1
# 3     545.0  4070794765468792359            137.26            4         1
# 4     545.0  4070794765468792359            205.92            4         1
#
#    order_state  charge_energy  charge_limit  charge_mode    charge_start_time  \
# 0           41          52.73         52.73            0  31/12/2018 23:12:25
# 1           41          61.89          0.00            0    1/1/2019 00:00:11
# 2           41           0.07          0.04            0  31/12/2018 23:37:16
# 3           41          68.63          0.00            0    1/1/2019 00:00:33
# 4           41         102.96          0.00            0    1/1/2019 00:00:35
#
#      charge_end_time create_time_t
# ...

# %%
df01 = df01.drop('order_state',axis=1)

# %%
df01.to_csv('D:/Work-Files/Data/充电订单-qs_charge_order数据/0901correct.csv',encoding='utf-8')

# %%
df01c = pd.read_csv('D:/Work-Files/Data/充电订单-qs_charge_order数据/1901correct.csv',encoding = 'utf-8')

# %%
df01c.describe()
# Out:
#           Unnamed: 0      owner_id  charge_total_fee    charge_type  \
# count  269665.000000  219760.00000     269665.000000  269665.000000
# mean   134832.000000    3908.98062         39.622017       3.066935
# std     77845.724508    5138.87633         46.641771       1.868452
# min         0.000000       0.00000          0.000000       1.000000
# 25%     67416.000000     350.00000         13.660000       2.000000
# 50%    134832.000000    1277.00000         30.190000       2.000000
# 75%    202248.000000    5844.00000         55.300000       4.000000
# max    269664.000000   16365.00000       9257.570000       7.000000
#
#             pay_type  charge_energy   charge_limit    charge_mode
# count  269665.000000  269665.000000  269665.000000  269665.000000
# mean        2.533414      36.787125    2518.291521       0.006137
# std         3.184442      37.389952   15354.241512       0.111005
# min         1.000000       0.000000       0.000000       0.000000
# ...

# %%
plt.figure(num=2, figsize=(8, 5));

# %%
plt.hist(df01c['charge_total_fee'],bins = 50,range=[0,500]);

# %%
df01c['charge_total_fee'].max()
# Out:
# 9257.57

# %%
df01c[df01c['charge_total_fee'] < 1].count()
# Out:
# Unnamed: 0           40915
# owner_id             36577
# station_id           40915
# charge_total_fee     40915
# charge_type          40915
# pay_type             40915
# charge_energy        40915
# charge_limit         40915
# charge_mode          40915
# charge_start_time    39662
# charge_end_time      39659
# create_time_t        40915
# dtype: int64

# %%
df01c[df01c['charge_total_fee'] > 1].count()
# Out:
# Unnamed: 0           228723
# owner_id             183163
# station_id           228723
# charge_total_fee     228723
# charge_type          228723
# pay_type             228723
# charge_energy        228723
# charge_limit         228723
# charge_mode          228723
# charge_start_time    228723
# charge_end_time      228723
# create_time_t        228723
# dtype: int64

# %%
df13 = pd.read_csv('D:/Work-Files/Data/充电订单-qs_charge_order数据/201901-0331qs_charge_order.csv',encoding='utf-8')

# %%
df13.describe()
# Out:
#             owner_id  charge_total_fee    charge_type       pay_type  \
# count  675136.000000     804498.000000  804498.000000  804498.000000
# mean     4337.123497         40.047626       3.127211       2.625390
# std      5492.417337         48.294238       1.904651       3.256219
# min         0.000000          0.000000       0.000000       1.000000
# 25%       350.000000         13.700000       2.000000       1.000000
# 50%      1895.000000         30.400000       2.000000       1.000000
# 75%      6444.000000         55.440000       4.000000       1.000000
# max     19366.000000       9270.980000       7.000000      10.000000
#
#          order_state  charge_energy   charge_limit    charge_mode
# count  804498.000000   804498.00000  804498.000000  804498.000000
# mean       40.962983       37.71147    2887.094462       0.005698
# std         0.583546       40.34033   16622.766905       0.105862
# min        12.000000        0.00000       0.000000       0.000000
# ...

# %%
df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804498 entries, 0 to 804497
# Data columns (total 13 columns):
# owner_id             675136 non-null float64
# station_id           804498 non-null object
# charge_total_fee     804498 non-null float64
# charge_type          804498 non-null int64
# pay_type             804498 non-null int64
# order_state          804498 non-null int64
# charge_energy        804498 non-null float64
# charge_limit         804498 non-null float64
# charge_mode          804498 non-null int64
# charge_start_time    801023 non-null object
# charge_end_time      801007 non-null object
# create_time          804498 non-null object
# update_time          802749 non-null object
# dtypes: float64(4), int64(4), object(5)
# memory usage: 79.8+ MB

# %%
#201901-0331充电费用小于1元的订单数量
df13[df13['charge_total_fee'] < 1].count()
# Out:
# owner_id             109962
# station_id           119289
# charge_total_fee     119289
# charge_type          119289
# pay_type             119289
# order_state          119289
# charge_energy        119289
# charge_limit         119289
# charge_mode          119289
# charge_start_time    115814
# charge_end_time      115798
# create_time          119289
# update_time          117807
# dtype: int64

# %%
#201901-0331充电费用小于0.1元的订单数量
df13[df13['charge_total_fee'] < 0.1].count()
# Out:
# owner_id              93267
# station_id           100778
# charge_total_fee     100778
# charge_type          100778
# pay_type             100778
# order_state          100778
# charge_energy        100778
# charge_limit         100778
# charge_mode          100778
# charge_start_time     97303
# charge_end_time       97287
# create_time          100778
# update_time           99310
# dtype: int64

# %%
df13[df13['charge_total_fee'] > 1].count()
# Out:
# owner_id             565067
# station_id           685086
# charge_total_fee     685086
# charge_type          685086
# pay_type             685086
# order_state          685086
# charge_energy        685086
# charge_limit         685086
# charge_mode          685086
# charge_start_time    685086
# charge_end_time      685086
# create_time          685086
# update_time          684819
# dtype: int64

# %%
df13[df13['charge_total_fee'] > 500].count()
# Out:
# owner_id             15
# station_id           15
# charge_total_fee     15
# charge_type          15
# pay_type             15
# order_state          15
# charge_energy        15
# charge_limit         15
# charge_mode          15
# charge_start_time    15
# charge_end_time      15
# create_time          15
# update_time          15
# dtype: int64

# %%
df13[df13['charge_total_fee'] > 1].to_csv('D:/190103bg1.csv',encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-97-4195758cb585> in <module>
# ----> 1 df13[df13['charge_total_fee'] > 1].to_csv('D:/190103bg1.csv',encoding='utf-8')
#
# D:\software\Anaconda-InstallFiles\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# D:\software\Anaconda-InstallFiles\lib\site-packages\pandas\io\formats\csvs.py in save(self)
# ...

# %%
df190103 = pd.read_csv('D:/190103.csv',encoding='utf-8',sep='\t')

# %%
df190103.describe()
# Out:
#           Unnamed: 0       owner_id    station_id  charge_total_fee  \
# count  685075.000000  565056.000000  5.404640e+05     685075.000000
# mean   401862.220570    4572.027787  5.607264e+18         46.898735
# std    231730.449278    5621.804107  2.303742e+18         39.068340
# min         0.000000       0.000000  3.710000e+17          1.010000
# 25%    202520.500000     348.000000  3.680000e+18         20.620000
# 50%    400113.000000    2114.000000  5.850000e+18         36.100000
# 75%    601431.500000    7941.000000  7.230000e+18         60.950000
# max    804497.000000   19366.000000  9.990000e+18        678.180000
#
#          charge_type       pay_type    order_state  charge_energy  \
# count  685075.000000  685075.000000  685075.000000  685075.000000
# mean        3.187311       2.727275      40.999714      41.874920
# std         1.964131       3.323346       0.016912      33.760028
# min         0.000000       1.000000      40.000000       0.020000
# ...

# %%
df190103.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 685075 entries, 0 to 685074
# Data columns (total 14 columns):
# Unnamed: 0           685075 non-null int64
# owner_id             565056 non-null float64
# station_id           540464 non-null float64
# charge_total_fee     685075 non-null float64
# charge_type          685075 non-null int64
# pay_type             685075 non-null int64
# order_state          685075 non-null int64
# charge_energy        685075 non-null float64
# charge_limit         685075 non-null float64
# charge_mode          685075 non-null int64
# charge_start_time    685075 non-null object
# charge_end_time      685075 non-null object
# create_time          685075 non-null object
# update_time          684808 non-null object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 73.2+ MB

# %%
plt.hist(df190103['charge_total_fee'],bins=40);

# %%
df190103['create_time'] = pd.to_datetime(df190103['create_time'])

# %%
df190103['create_time'].head()
# Out:
# 0   2019-02-28 12:53:06
# 1   2019-03-19 17:45:53
# 2   2019-06-03 09:21:35
# 3   2019-01-03 12:40:47
# 4   2019-05-03 08:20:11
# Name: create_time, dtype: datetime64[ns]

# %%
df190103['create_time01'] = pd.to_datetime(df190103['create_time']).dt.time

# %%
df190103['create_time01'].head()
# Out:
# 0    12:53:06
# 1    17:45:53
# 2    09:21:35
# 3    12:40:47
# 4    08:20:11
# Name: create_time01, dtype: object

# %%
df190103 = df190103.drop('create_time',axis=1)

# %%
df190103.to_csv('D:/time0103.csv',encoding='utf-8',sep=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dc6c4e62c3b5> in <module>
# ----> 1 df190103.to_csv('D:/time0103.csv',encoding='utf-8',sep=',')
#
# NameError: name 'df190103' is not defined

# %%
df190103['pay_type'].count()
# Out:
# 685075

# %%
df190103['pay_type'].describe()
# Out:
# count    685075.000000
# mean          2.727275
# std           3.323346
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          10.000000
# Name: pay_type, dtype: float64

# %%
df190103['station_id'].describe()
# Out:
# count    5.404640e+05
# mean     5.607264e+18
# std      2.303742e+18
# min      3.710000e+17
# 25%      3.680000e+18
# 50%      5.850000e+18
# 75%      7.230000e+18
# max      9.990000e+18
# Name: station_id, dtype: float64

# %%
df0103 = pd.read_csv('D:/time0103.csv',encoding = 'utf-8')

# %%
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  owner_id    station_id  charge_total_fee  \
# 0           0        504421       0.0           NaN            678.18
# 1           1        693282    5790.0  7.140000e+18            543.02
# 2           2        559574     545.0  4.070000e+18            538.26
#
#    charge_type  pay_type  order_state  charge_energy  charge_limit  \
# 0            4         1           41         339.09           0.0
# 1            2         1           41         339.39           0.0
# 2            4         1           41         269.13           0.0
#
#    charge_mode   charge_start_time     charge_end_time         update_time  \
# 0            0  28/2/2019 12:53:03  28/2/2019 15:53:41  28/2/2019 15:53:43
# 1            0  19/3/2019 17:45:56  20/3/2019 09:12:55  20/3/2019 09:12:58
# 2            0   6/3/2019 09:21:31   6/3/2019 12:05:40   6/3/2019 12:05:44
#
#          create_time_t create_time01
# 0  2019-02-28 12:53:06      12:53:06
# ...

# %%
df343 = df[df['owner_id']==343]

# %%
df343.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43681 entries, 8395 to 685014
# Data columns (total 16 columns):
# Unnamed: 0           43681 non-null int64
# Unnamed: 0.1         43681 non-null int64
# owner_id             43681 non-null float64
# station_id           43681 non-null float64
# charge_total_fee     43681 non-null float64
# charge_type          43681 non-null int64
# pay_type             43681 non-null int64
# order_state          43681 non-null int64
# charge_energy        43681 non-null float64
# charge_limit         43681 non-null float64
# charge_mode          43681 non-null int64
# charge_start_time    43681 non-null object
# charge_end_time      43681 non-null object
# update_time          43681 non-null object
# create_time_t        43681 non-null object
# create_time01        43681 non-null object
# dtypes: float64(5), int64(6), object(5)
# memory usage: 5.7+ MB

# %%
df343.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1  owner_id    station_id  charge_total_fee  \
# count   43681.000000   43681.000000   43681.0  4.368100e+04      43681.000000
# mean   350894.755225  394455.374877     343.0  3.291865e+18         42.525846
# std    175556.936420  233165.872789       0.0  1.815684e+18         28.746499
# min      8395.000000    1014.000000     343.0  2.730000e+18          1.020000
# 25%    205013.000000  191117.000000     343.0  2.730000e+18         22.600000
# 50%    382803.000000  385704.000000     343.0  2.730000e+18         32.110000
# 75%    490666.000000  594143.000000     343.0  2.730000e+18         54.750000
# max    685014.000000  804375.000000     343.0  9.610000e+18        184.410000
#
#         charge_type      pay_type  order_state  charge_energy  charge_limit  \
# count  43681.000000  43681.000000      43681.0   43681.000000  43681.000000
# mean       1.999977      1.000206         41.0      35.459942     31.362936
# ...

# %%
df343.head()
# Out:
#       Unnamed: 0  Unnamed: 0.1  owner_id    station_id  charge_total_fee  \
# 8395        8395        412441     343.0  2.730000e+18            184.41
# 8644        8644         95487     343.0  2.730000e+18            183.36
# 9061        9061        409073     343.0  2.730000e+18            181.71
# 9141        9141        386262     343.0  2.730000e+18            181.44
# 9391        9391        419052     343.0  2.730000e+18            180.38
#
#       charge_type  pay_type  order_state  charge_energy  charge_limit  \
# 8395            2         1           41         153.70        184.41
# 8644            2         1           41         152.80        183.36
# 9061            2         1           41         151.56        181.71
# 9141            2         1           41         151.27        181.44
# 9391            2         1           41         150.32        180.38
#
#       charge_mode   charge_start_time     charge_end_time         update_time  \
# ...

# %%
df343['station_id'] = df343['station_id']/10000000000000000
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df343['station_id'].head()
# Out:
# 8395    273.0
# 8644    273.0
# 9061    273.0
# 9141    273.0
# 9391    273.0
# Name: station_id, dtype: float64

# %%
df343.to_csv('D:/owner_id343.csv',encoding='utf-8')

# %%
df343 = pd.read_csv('D:/owner_id343.csv',encoding='utf-8')

# %%
df343.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  owner_id    station_id  \
# 0        8395          8395          412441     343.0  2.730000e+18
# 1        8644          8644           95487     343.0  2.730000e+18
#
#    charge_total_fee  charge_type  pay_type  order_state  charge_energy  \
# 0            184.41            2         1           41          153.7
# 1            183.36            2         1           41          152.8
#
#    charge_limit  charge_mode   charge_start_time     charge_end_time  \
# 0        184.41            0   0/1/2000 10:53:23   0/1/2000 12:15:03
# 1        183.36            0  11/1/2019 12:17:29  11/1/2019 13:39:11
#
#           update_time        create_time_t create_time01
# 0  18/2/2019 19:10:23  2019-02-18 19:10:23      19:10:23
# 1  11/1/2019 13:45:15  2019-11-01 13:45:15      13:45:15

# %%
df343['create_time01'].head()
# Out:
# 0    19:10:23
# 1    13:45:15
# 2    13:16:27
# 3    18:41:05
# 4    13:36:21
# Name: create_time01, dtype: object

# %%
df343['create_time01'] = pd.to_datetime(df343['create_time01']) 
df343['create_time01'] = df343['create_time01'].dt.time

# %%
df343['charge_energy'].describe()
# Out:
# count    43681.000000
# mean        35.459942
# std         23.957482
# min          0.850000
# 25%         18.850000
# 50%         26.770000
# 75%         45.640000
# max        153.700000
# Name: charge_energy, dtype: float64

# %%
#江苏镇江四个站点
df343['charge_total_fee'].describe()
# Out:
# count    43681.000000
# mean        42.525846
# std         28.746499
# min          1.020000
# 25%         22.600000
# 50%         32.110000
# 75%         54.750000
# max        184.410000
# Name: charge_total_fee, dtype: float64

# %%
#上海10个站点
df346 = df[df['owner_id']==346]

# %%
df346.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17049 entries, 214 to 684891
# Data columns (total 16 columns):
# Unnamed: 0           17049 non-null int64
# Unnamed: 0.1         17049 non-null int64
# owner_id             17049 non-null float64
# station_id           17049 non-null float64
# charge_total_fee     17049 non-null float64
# charge_type          17049 non-null int64
# pay_type             17049 non-null int64
# order_state          17049 non-null int64
# charge_energy        17049 non-null float64
# charge_limit         17049 non-null float64
# charge_mode          17049 non-null int64
# charge_start_time    17049 non-null object
# charge_end_time      17049 non-null object
# update_time          17047 non-null object
# create_time_t        17049 non-null object
# create_time01        17049 non-null object
# dtypes: float64(5), int64(6), object(5)
# memory usage: 2.2+ MB

# %%
df346.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1  owner_id    station_id  charge_total_fee  \
# count   17049.000000   17049.000000   17049.0  1.704900e+04      17049.000000
# mean   208407.373570  408620.777993     346.0  4.861541e+18         82.836064
# std    209263.970055  235550.910001       0.0  2.500002e+18         56.472807
# min       214.000000      33.000000     346.0  1.140000e+18          1.030000
# 25%     30675.000000  193446.000000     346.0  2.990000e+18         36.340000
# 50%    127231.000000  425202.000000     346.0  3.300000e+18         71.300000
# 75%    340294.000000  616088.000000     346.0  7.050000e+18        123.620000
# max    684891.000000  804123.000000     346.0  9.510000e+18        382.380000
#
#         charge_type      pay_type   order_state  charge_energy  charge_limit  \
# count  17049.000000  17049.000000  17049.000000   17049.000000  17049.000000
# mean       2.078128      1.142002     40.999648      51.605096   8608.375096
# ...

# %%
#owner_id=346 上海
df346.to_csv('D:/owner_id346shanghai.csv',encoding='utf-8')

# %%
df346 = pd.read_csv('D:/owner_id346shanghai.csv',encoding='utf-8')

# %%
df346['create_time01'] = pd.to_datetime(df346['create_time01']) 
df346['create_time01'] = df346['create_time01'].dt.time

# %%
#owner_id=346上海场站 主要是商旅
df346.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1  Unnamed: 0.1.1  owner_id    station_id  \
# count   17049.000000   17049.000000    17049.000000   17049.0  1.704900e+04
# mean   208407.373570  208407.373570   408620.777993     346.0  4.861541e+18
# std    209263.970055  209263.970055   235550.910001       0.0  2.500002e+18
# min       214.000000     214.000000       33.000000     346.0  1.140000e+18
# 25%     30675.000000   30675.000000   193446.000000     346.0  2.990000e+18
# 50%    127231.000000  127231.000000   425202.000000     346.0  3.300000e+18
# 75%    340294.000000  340294.000000   616088.000000     346.0  7.050000e+18
# max    684891.000000  684891.000000   804123.000000     346.0  9.510000e+18
#
#        charge_total_fee   charge_type      pay_type   order_state  \
# count      17049.000000  17049.000000  17049.000000  17049.000000
# mean          82.836064      2.078128      1.142002     40.999648
# std           56.472807      0.321848      1.121575      0.018757
# ...

# %%
df190103['owner_id'] == 3550
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-bdc792bb7ab9> in <module>
# ----> 1 df190103['owner_id'] == 3550
#
# NameError: name 'df190103' is not defined

# %%
df344 = df0103[df0103['owner_id'] == 344]

# %%
df344.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1  owner_id    station_id  charge_total_fee  \
# count   22871.000000   22871.000000   22871.0  2.287100e+04      22871.000000
# mean   397424.470727  407204.402781     344.0  4.351243e+18         36.525662
# std    164730.604543  231061.974530       0.0  2.449230e+18         29.935044
# min      1962.000000     104.000000     344.0  5.810000e+17          1.010000
# 25%    305094.500000  207677.500000     344.0  1.460000e+18         20.830000
# 50%    412151.000000  415963.000000     344.0  4.050000e+18         29.630000
# 75%    511323.000000  608460.000000     344.0  5.560000e+18         40.390000
# max    685059.000000  804441.000000     344.0  9.930000e+18        253.070000
#
#         charge_type      pay_type   order_state  charge_energy   charge_limit  \
# count  22871.000000  22871.000000  22871.000000   22871.000000   22871.000000
# mean       1.882340      3.190678     40.998295      27.581866   11355.756594
# ...

# %%
df344.to_csv('D:/owner_id344nanjing.csv',encoding='utf-8')

# %%
#owner_id = 344 南京
df344 = pd.read_csv('D:/owner_id344nanjing.csv',encoding='utf-8')

# %%
df344.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  owner_id    station_id  \
# 0        1962          1962          621767     344.0  1.420000e+18
# 1        2087          2087          693724     344.0  1.420000e+18
#
#    charge_total_fee  charge_type  pay_type  order_state  charge_energy  \
# 0            253.07            2         1           41         194.67
# 1            249.42            2         1           41         191.86
#
#    charge_limit  charge_mode   charge_start_time     charge_end_time  \
# 0           0.0            0  12/3/2019 14:38:43  12/3/2019 16:20:04
# 1           0.0            0  19/3/2019 18:30:08  19/3/2019 21:31:25
#
#           update_time        create_time_t create_time01
# 0  12/3/2019 16:52:07  2019-12-03 14:38:44      14:38:44
# 1  19/3/2019 22:00:54  2019-03-19 18:30:11      18:30:11

# %%
df344['charge_start_time'] = pd.to_datetime(df344['charge_start_time'])
df344['charge_end_time'] = pd.to_datetime(df344['charge_end_time'])

# %%
df344['charge_start_time'] = df344['charge_start_time'].dt.time
df344['charge_end_time'] = df344['charge_end_time'].dt.time

# %%
df344.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  owner_id    station_id  \
# 0        1962          1962          621767     344.0  1.420000e+18
# 1        2087          2087          693724     344.0  1.420000e+18
#
#    charge_total_fee  charge_type  pay_type  order_state  charge_energy  \
# 0            253.07            2         1           41         194.67
# 1            249.42            2         1           41         191.86
#
#    charge_limit  charge_mode charge_start_time charge_end_time  \
# 0           0.0            0          14:38:43        16:20:04
# 1           0.0            0          18:30:08        21:31:25
#
#           update_time        create_time_t create_time01
# 0  12/3/2019 16:52:07  2019-12-03 14:38:44      14:38:44
# 1  19/3/2019 22:00:54  2019-03-19 18:30:11      18:30:11

# %%
df344['end_start'] = pd.to_datetime(df344['charge_end_time'], format='%H:%M:%S')-pd.to_datetime(df344['charge_start_time'], format='%H:%M:%S')

# %%
df344.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  owner_id    station_id  \
# 0        1962          1962          621767     344.0  1.420000e+18
# 1        2087          2087          693724     344.0  1.420000e+18
# 2        2187          2187          601794     344.0  1.420000e+18
#
#    charge_total_fee  charge_type  pay_type  order_state  charge_energy  \
# 0            253.07            2         1           41         194.67
# 1            249.42            2         1           41         191.86
# 2            246.60            2         1           41         189.69
#
#    charge_limit  charge_mode charge_start_time charge_end_time  \
# 0           0.0            0          14:38:43        16:20:04
# 1           0.0            0          18:30:08        21:31:25
# 2           0.0            0          14:27:31        16:51:31
#
#           update_time        create_time_t create_time01 end_start
# 0  12/3/2019 16:52:07  2019-12-03 14:38:44      14:38:44  01:41:21
# ...

# %%
df344.to_csv('D:/owner_id344nanjing.csv',encoding='utf-8')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
plt.rcParams['font.sans-serif']=['SimHei']                           # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False                             # 用来正常显示负号

# %%
file = 'D:/Work-Files/Data/qs_charge_order/20190103qs_charge_order.csv'
#读取文件
df0103 = pd.read_csv(file,encoding='utf-8')

# %%
df0103.head(3)
# Out:
#                          id   uid  bind_uid         code  owner_id  \
# 0  702089801074181231231225  1895       NaN   2.0898e+09    1895.0
# 1  41807884000002005C2A3D0B     0       NaN            0       0.0
# 2  000090001398181231233716     0       NaN  9.00014e+07    8221.0
#
#        pile_id           station_id  charge_port_index  order_state  \
# 0  18031210000  3406694328833234077                  2           41
# 1  18078840000                                       2           41
# 2  17102800000  3977393150786253008                  2           41
#
#    charge_mode  ...  real_sub_fee on_time_charge_ret total_score last_soc  \
# 0            0  ...             0                  0           0    100.0
# 1            0  ...             0                  0           0    100.0
# 2            0  ...             0                  0           0     94.0
#
#   begin_soc        insert_time  thirdorderid user_fee  OrderResult  \
# ...

# %%
df0103.describe()
# Out:
#                  uid      bind_uid       owner_id  charge_port_index  \
# count  804498.000000    856.000000  675136.000000      804498.000000
# mean     1959.129108  11661.987150    4337.123497           1.573974
# std      4170.180495   4329.016422    5492.417337           0.771332
# min         0.000000   3685.000000       0.000000           0.000000
# 25%         0.000000  12696.000000     350.000000           1.000000
# 50%         0.000000  12696.000000    1895.000000           1.000000
# 75%      2113.000000  12696.000000    6444.000000           2.000000
# max     19913.000000  18394.000000   19366.000000           8.000000
#
#          order_state    charge_mode   charge_limit  cancel_time  \
# count  804498.000000  804498.000000  804498.000000          0.0
# mean       40.963105       0.005698    2887.094462          NaN
# std         0.582628       0.105862   16622.766905          NaN
# min        12.000000       0.000000       0.000000          NaN
# ...

# %%
df0103.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804498 entries, 0 to 804497
# Data columns (total 47 columns):
# id                         804498 non-null object
# uid                        804498 non-null int64
# bind_uid                   856 non-null float64
# code                       795391 non-null object
# owner_id                   675136 non-null float64
# pile_id                    804498 non-null object
# station_id                 804498 non-null object
# charge_port_index          804498 non-null int64
# order_state                804498 non-null int64
# charge_mode                804498 non-null int64
# charge_limit               804498 non-null float64
# reserve_start_time         12 non-null object
# reserve_end_time           12 non-null object
# charge_start_time          801030 non-null object
# charge_end_time            801014 non-null object
# cancel_time                0 non-null float64
# cancel_reason              804498 non-null int64
# ...

# %%
df0103['charge_start_time'].head(3)
# Out:
# 0    31/12/2018 23:12:25
# 1      1/1/2019 00:00:11
# 2    31/12/2018 23:37:16
# Name: charge_start_time, dtype: object

# %%
# df0103 = df0103.drop('pay_reserve_type',axis = 1)
df0103 = df0103.drop('insert_time',axis = 1)
# df0103 = df0103.drop('on_time_charge_ret',axis = 1)
# df0103 = df0103.drop('total_score',axis = 1)
# df0103 = df0103.drop('thirdorderid',axis = 1)
# df0103 = df0103.drop('user_fee',axis = 1)

# %%
df0103.head(2)
# Out:
#                          id   uid        code  owner_id      pile_id  \
# 0  702089801074181231231225  1895  2.0898e+09    1895.0  18031210000
# 1  41807884000002005C2A3D0B     0           0       0.0  18078840000
#
#             station_id  charge_limit    charge_start_time    charge_end_time  \
# 0  3406694328833234077         52.73  31/12/2018 23:12:25  1/1/2019 00:00:01
# 1                               0.00    1/1/2019 00:00:11  1/1/2019 01:58:32
#
#    charge_energy  charge_total_fee  charge_type        create_time  \
# 0          52.73             52.73            7  1/1/2019 00:00:05
# 1          61.89            123.78            4  1/1/2019 00:00:14
#
#          update_time  pay_type  last_soc  begin_soc OrderResult  \
# 0  1/1/2019 00:00:04         9     100.0       65.0          00
# 1  1/1/2019 01:58:35         1     100.0       15.0          00
#
#                               VINCode
# 0  4C4857434A393544334831313732303437
# 1  4C4C334145434A33384741303033343532

# %%
df0103.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804498 entries, 0 to 804497
# Data columns (total 21 columns):
# id                   804498 non-null object
# uid                  804498 non-null int64
# bind_uid             856 non-null float64
# code                 795391 non-null object
# owner_id             675136 non-null float64
# pile_id              804498 non-null object
# station_id           804498 non-null object
# charge_limit         804498 non-null float64
# charge_start_time    801030 non-null object
# charge_end_time      801014 non-null object
# charge_energy        804498 non-null float64
# charge_total_fee     804498 non-null float64
# charge_type          804498 non-null int64
# create_time          804498 non-null object
# update_time          802755 non-null object
# pay_type             804498 non-null int64
# last_soc             800743 non-null float64
# begin_soc            800741 non-null float64
# insert_time          804498 non-null object
# ...

# %%
df0103.describe()
# Out:
#                  uid      bind_uid       owner_id   charge_limit  \
# count  804498.000000    856.000000  675136.000000  804498.000000
# mean     1959.129108  11661.987150    4337.123497    2887.094462
# std      4170.180495   4329.016422    5492.417337   16622.766905
# min         0.000000   3685.000000       0.000000       0.000000
# 25%         0.000000  12696.000000     350.000000       0.000000
# 50%         0.000000  12696.000000    1895.000000       0.000000
# 75%      2113.000000  12696.000000    6444.000000      27.350000
# max     19913.000000  18394.000000   19366.000000  235900.000000
#
#        charge_energy  charge_total_fee    charge_type       pay_type  \
# count  804498.000000     804498.000000  804498.000000  804498.000000
# mean       37.711722         40.047970       3.127211       2.625390
# std        40.340231         48.294181       1.904651       3.256219
# min         0.000000          0.000000       0.000000       1.000000
# ...

# %%
df0103['charge_limit'].max()
# Out:
# 235900.0

# %%
df0103.to_csv('D:/Work-Files/Data/qs_charge_order/correct_charge_order0103.csv',encoding='utf-8')

# %%
file = 'D:/Work-Files/Data/qs_charge_order/correct_charge_order0103.csv'
#读取文件
correct0103 = pd.read_csv(file,encoding='utf-8')
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
correct0103.describe()
# Out:
#          Unnamed: 0            uid       owner_id   charge_limit  \
# count  804498.00000  804498.000000  675136.000000  804498.000000
# mean   402248.50000    1959.129108    4337.123497    2887.094462
# std    232238.71277    4170.180495    5492.417337   16622.766905
# min         0.00000       0.000000       0.000000       0.000000
# 25%    201124.25000       0.000000     350.000000       0.000000
# 50%    402248.50000       0.000000    1895.000000       0.000000
# 75%    603372.75000    2113.000000    6444.000000      27.350000
# max    804497.00000   19913.000000   19366.000000  235900.000000
#
#        charge_energy  charge_total_fee    charge_type       pay_type  \
# count  804498.000000     804498.000000  804498.000000  804498.000000
# mean       37.711722         40.047970       3.127211       2.625390
# std        40.340231         48.294181       1.904651       3.256219
# min         0.000000          0.000000       0.000000       1.000000
# ...

# %%
correct0103.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804498 entries, 0 to 804497
# Data columns (total 20 columns):
# Unnamed: 0           804498 non-null int64
# id                   804498 non-null object
# uid                  804498 non-null int64
# code                 795391 non-null object
# owner_id             675136 non-null float64
# pile_id              804498 non-null object
# station_id           804498 non-null object
# charge_limit         804498 non-null float64
# charge_start_time    801030 non-null object
# charge_end_time      801014 non-null object
# charge_energy        804498 non-null float64
# charge_total_fee     804498 non-null float64
# charge_type          804498 non-null int64
# create_time          804498 non-null object
# update_time          802755 non-null object
# pay_type             804498 non-null int64
# last_soc             800743 non-null float64
# begin_soc            800741 non-null float64
# OrderResult          701183 non-null object
# ...

# %%
correct0103[correct0103['charge_energy'] < 1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92036 entries, 2 to 804496
# Data columns (total 20 columns):
# Unnamed: 0           92036 non-null int64
# id                   92036 non-null object
# uid                  92036 non-null int64
# code                 88782 non-null object
# owner_id             82834 non-null float64
# pile_id              92036 non-null object
# station_id           92036 non-null object
# charge_limit         92036 non-null float64
# charge_start_time    88568 non-null object
# charge_end_time      88552 non-null object
# charge_energy        92036 non-null float64
# charge_total_fee     92036 non-null float64
# charge_type          92036 non-null int64
# create_time          92036 non-null object
# update_time          90557 non-null object
# pay_type             92036 non-null int64
# last_soc             88522 non-null float64
# begin_soc            88522 non-null float64
# OrderResult          80504 non-null object
# ...

# %%
correct0103[correct0103['charge_total_fee'] < 0.1].count()
# Out:
# Unnamed: 0           100772
# id                   100772
# uid                  100772
# code                  97924
# owner_id              93261
# pile_id              100772
# station_id           100772
# charge_limit         100772
# charge_start_time     97304
# charge_end_time       97288
# charge_energy        100772
# charge_total_fee     100772
# charge_type          100772
# create_time          100772
# update_time           99311
# pay_type             100772
# last_soc              97275
# begin_soc             97275
# OrderResult           89602
# VINCode               89602
# dtype: int64

# %%
correct0103[correct0103['charge_total_fee'] < 1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119283 entries, 2 to 804496
# Data columns (total 20 columns):
# Unnamed: 0           119283 non-null int64
# id                   119283 non-null object
# uid                  119283 non-null int64
# code                 116085 non-null object
# owner_id             109956 non-null float64
# pile_id              119283 non-null object
# station_id           119283 non-null object
# charge_limit         119283 non-null float64
# charge_start_time    115815 non-null object
# charge_end_time      115799 non-null object
# charge_energy        119283 non-null float64
# charge_total_fee     119283 non-null float64
# charge_type          119283 non-null int64
# create_time          119283 non-null object
# update_time          117808 non-null object
# pay_type             119283 non-null int64
# last_soc             115772 non-null float64
# begin_soc            115772 non-null float64
# OrderResult          106428 non-null object
# ...

# %%
correct0103[correct0103['charge_total_fee'] > 1].to_csv('D:/Work-Files/Data/qs_charge_order/correct_order0103.csv',encoding='utf-8')

# %%
file = 'D:/Work-Files/Data/qs_charge_order/correct0103.csv'
#读取文件
correct0103 = pd.read_csv(file,encoding='utf-8',sep='\t')
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
correct0103.describe()
# Out:
#           Unnamed: 0            uid       owner_id    station_id  \
# count  685092.000000  685092.000000  565073.000000  5.404810e+05
# mean   401866.911251    2069.620914    4571.907506  5.607236e+18
# std    231732.434819    4284.884506    5621.764397  2.303737e+18
# min         0.000000       0.000000       0.000000  3.710000e+17
# 25%    202521.750000       0.000000     348.000000  3.680000e+18
# 50%    400118.500000       0.000000    2114.000000  5.850000e+18
# 75%    601441.500000    2113.000000    7941.000000  7.230000e+18
# max    804497.000000   19913.000000   19366.000000  9.990000e+18
#
#         charge_limit  charge_energy  charge_total_fee    charge_type  \
# count  685092.000000  685092.000000     685092.000000  685092.000000
# mean     2040.824171      41.954459         47.016210       3.187281
# std     14006.897475      40.872436         49.108859       1.964116
# min         0.000000       0.020000          1.010000       0.000000
# ...

# %%
correct0103.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 685092 entries, 0 to 685091
# Data columns (total 19 columns):
# Unnamed: 0           685092 non-null int64
# uid                  685092 non-null int64
# code                 679186 non-null object
# owner_id             565073 non-null float64
# pile_id              685092 non-null object
# station_id           540481 non-null float64
# charge_limit         685092 non-null float64
# charge_start_time    685092 non-null object
# charge_end_time      685092 non-null object
# charge_energy        685092 non-null float64
# charge_total_fee     685092 non-null float64
# charge_type          685092 non-null int64
# create_time          685092 non-null object
# update_time          684824 non-null object
# pay_type             685092 non-null int64
# last_soc             684848 non-null float64
# begin_soc            684846 non-null float64
# OrderResult          594634 non-null object
# VINCode              594634 non-null object
# ...

# %%
correct0103[correct0103['owner_id']==343].to_csv('D:/Work-Files/Data/owid343.csv',encoding='utf-8')

# %%
correct0103[correct0103['begin_soc'] == 100].count()
# Out:
# Unnamed: 0           289
# uid                  289
# code                 284
# owner_id             267
# pile_id              289
# station_id           249
# charge_limit         289
# charge_start_time    289
# charge_end_time      289
# charge_energy        289
# charge_total_fee     289
# charge_type          289
# create_time          289
# update_time          289
# pay_type             289
# last_soc             289
# begin_soc            289
# OrderResult          254
# VINCode              254
# dtype: int64
