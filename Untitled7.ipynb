# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# #一个场站数据
std = df[df['station_id']==8666323774228486052]
#单个场站的一个月份数据
std_01 = std[std['start_month']==1]
#单个场站一个月份的一个时间段数据
std_01_t1 = std_01[(std_01['start_hour'] > 0) & (std_01['start_hour'] < 6)]
print(std_01_t1['charge_energy'].sum())
print(std_01_t1['charge_total_fee'].sum())
# Out:
# 2130.75
# 1952.1999999999998

# %%
#2019年1-5/14订单中，每个场站每个月每个时间段充电度数和费用
with open('D:/station/sichuan_station.txt',encoding='utf-8') as f:
    read_std = f.readlines()
    for i in range(len(read_std)):
        #一个场站数据
        std = df[df['station_id']==int(read_std[i])]
        std = pd.DataFrame(std,dtype=np.float)
        
            #单个场站的1个月份数据
        std_01 = std[std['start_month']==5]
        #单个场站一个月份的各个时间段数据
        std_01_f = std_01[(std_01['start_hour'] >= 7) & (std_01['start_hour'] < 11) | (std_01['start_hour'] >= 19) & (std_01['start_hour'] < 23)]
        std_01_p = std_01[(std_01['start_hour'] >= 11) & (std_01['start_hour'] < 19)]
        std_01_g = std_01[(std_01['start_hour'] >= 0) & (std_01['start_hour'] < 7)  | (std_01['start_hour'] >= 23)]
        
#             result = ('station_id:,',int(read_std[i]),'charge_energy:',std_01_t1['charge_energy'].sum(),'charge_total_fee:',std_01_t1['charge_total_fee'].sum())
        result = (std_01_f['charge_energy'].sum(),std_01_p['charge_energy'].sum(),std_01_g['charge_energy'].sum())
        result = pd.DataFrame(result)
        result.to_csv('D:/sichuanenergy05_order.txt',mode='a',float_format='%.1f')

# %%
with open('D:/station/jiangsu_station.txt','r') as f:
    with open('D:/js_rd.txt','w') as f1:
            for i in range(156):
                js_rd = f.readline()     
                f1.writelines(js_rd + '\n' + '\n' + '\n')

# %%
order = pd.read_csv('D:/data.txt',sep='\t')

# %%
order.head(3)
# Out:
#              stationid      1月份  1月份占比  1月份峰谷价差      2月份  2月份占比  2月份峰谷价差  \
# 0  2843840167506263070  37255.9  61.18    26563  26219.9  66.42    18695
# 1  3297739315078625300  16981.6  36.72    12108  14232.9  40.86    10148
# 2  9060677044143051400  24329.2  70.07    17347  12012.1  69.52     8565
#
#        3月份  3月份占比  3月份峰谷价差      4月份  4月份占比  4月份峰谷价差      5月份  5月份占比  5月份峰谷价差  \
# 0  33049.6  67.01    23564  32505.6  69.43    23176  11164.3  71.87     7960
# 1  20382.6  41.67    14533  21481.6  44.12    15316   9766.9  42.95     6964
# 2  19587.5  73.78    13966  18403.4  81.40    13122   6104.7  77.67     4353
#
#    Unnamed: 16
# 0          NaN
# 1          NaN
# 2          NaN

# %%
plt.style.use('ggplot')
plt.rcParams['font.sans-serif']=['SimHei'] # 用来正常显示中文字体标签（全局设置） 
plt.rcParams['axes.unicode_minus']=False # 用来正常显示负号

# %%
x=[1,1,1,3,3,3,2,2.1,3,5,1.2,2.5,2,1.7,1.6,2.4]
y=[1.1,1.2,3.0,4.1,4.2,4.3,1.9,2,7,4,5,2.9,3.2,3.9,6]
cValue = ['c','y','r','b','g','m']  

for i in range(len(y)):
    if y[i] < 3:
        plt.scatter(x[i],y[i],c=cValue[0])
    if y[i] == 3:
        plt.scatter(x[i],y[i],c=cValue[1])
    if y[i] > 3:
        plt.scatter(x[i],y[i],c=cValue[2],marker='s')

# %%
from wordcloud import WordCloud

# %%
f = open('D:/word.txt','r',encoding='utf-8').read()

# %%
wordcloud = WordCloud(font_path="C:/Windows/Fonts/simfang.ttf",
    background_color='white',
                     width=1500,
                     height=960,
                     margin=10).generate(f)

# %%
plt.axis('off')
plt.imshow(wordcloud);

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
X_train,X_test,y_train,y_test = train_test_split(iris.data,iris.target,random_state=0)

# %%
print(X_train.shape)
# Out:
# (112, 4)

# %%
print('mean:%s' %X_train.mean(axis=0))
print('standard deviation:%s'%X_train.std(axis=0))
# Out:
# mean:[5.88660714 3.05178571 3.79642857 1.22321429]
# standard deviation:[0.86741565 0.43424445 1.79264014 0.77793019]

# %%
df = pd.read_csv('D:/chargeorder/station0581_2019.txt',encoding='utf-8',sep='\t')
df.head(2)
# Out:
#    charge_energy  begin_soc  last_soc  charge_start_day charge_start_month  \
# 0          60.73         69       100                 4                  1
# 1          50.66         48        98                 4                  1
#
#   charge_start_year charge_start_time
# 0              2019          08:50:04
# 1              2019          09:31:32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58086 entries, 0 to 58085
# Data columns (total 7 columns):
# charge_energy         58086 non-null float64
# begin_soc             58086 non-null int64
# last_soc              58086 non-null int64
# charge_start_day      58086 non-null int64
# charge_start_month    58086 non-null object
# charge_start_year     58086 non-null object
# charge_start_time     58074 non-null object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.1+ MB

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58074 entries, 0 to 58085
# Data columns (total 7 columns):
# charge_energy         58074 non-null float64
# begin_soc             58074 non-null int64
# last_soc              58074 non-null int64
# charge_start_day      58074 non-null int64
# charge_start_month    58074 non-null object
# charge_start_year     58074 non-null object
# charge_start_time     58074 non-null int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 3.5+ MB

# %%
df['charge_start_time'] = pd.to_datetime(df['charge_start_time'])
df['charge_start_time'] =df['charge_start_time'].dt.hour

# %%
df.describe()
# Out:
#        charge_energy     begin_soc      last_soc  charge_start_day  \
# count   58074.000000  58074.000000  58074.000000      58074.000000
# mean       34.779778     59.340204     96.654010         15.493612
# std        22.914810     14.341252      7.425977          8.693510
# min         1.000000      0.000000      0.000000          1.000000
# 25%        19.310000     49.000000     98.000000          8.000000
# 50%        26.520000     59.000000     99.000000         16.000000
# 75%        44.080000     70.000000    100.000000         23.000000
# max       152.800000    100.000000    100.000000         31.000000
#
#        charge_start_time
# count       58074.000000
# mean           13.171832
# std             3.774908
# min             0.000000
# 25%            10.000000
# 50%            13.000000
# 75%            17.000000
# max            23.000000

# %%
df[df['last_soc'] == 0].index
# Out:
# Int64Index([28498, 47637, 54256, 56803, 57314, 57339, 57989], dtype='int64')

# %%
df = df.drop(index=[28498, 47637, 54256, 56803, 57314, 57339, 57989])

# %%
df['charge_energy'].plot();

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = df[['begin_soc','last_soc','charge_start_day','charge_start_month','charge_start_time']]
y = df[['charge_energy']]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
print('X_train.shape:',X_train.shape,'| ','X_test.shape:',X_test.shape,'| ','y_train.shape:',y_train.shape,'| ','X_train.shape:',y_test.shape,)
linreg = LinearRegression()
#进行训练
linreg.fit(X_train,y_train)
#训练模型完毕，查看模型截距
print('模型截距为：',linreg.intercept_)
#模型权重
print('各特征的权重为：',linreg.coef_)
y_pred = linreg.predict(X_test)
from sklearn import metrics
#使用sklearn 计算均方差(mse)或均方根差(rmse)
print('方差 mse:',metrics.mean_squared_error(y_test,y_pred))
print('均方根差 rmse:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# X_train.shape: (40644, 5) |  X_test.shape: (17419, 5) |  y_train.shape: (40644, 1) |  X_train.shape: (17419, 1)
# 模型截距为： [12.57256417]
# 各特征的权重为： [[-0.71641756  0.60231896 -0.00933574  0.18327774  0.45618623]]
# 方差 mse: 404.01917754900103
# 均方根差 rmse: 20.100228295942337

# %%
#交叉验证
from sklearn.model_selection import cross_val_predict
predicted = cross_val_predict(linreg,X,y,cv=10)
#使用sklearn 计算均方差(mse)或均方根差(rmse)
print('mse:',metrics.mean_squared_error(y,predicted))
print('rmse:',np.sqrt(metrics.mean_squared_error(y,predicted)))
# Out:
# mse: 434.8671034456153
# rmse: 20.853467420206535

# %%
#画图查看结果
fig,ax = plt.subplots()
ax.scatter(y,predicted)
ax.plot([y.min(),y.max()],[y.min(),y.max()],'k--',lw=4)
ax.set_xlabel('measured')
ax.set_ylabel('predicted')
plt.show()

# %%
score_ = linreg.score(X_test,y_test)
print('模型得分：',score_)
y_pred = linreg.predict(X_test)
print('模型预测：',y_pred)
# Out:
# 模型得分： 0.23969330498374117
# 模型预测： [[28.02577297]
#  [34.93365973]
#  [55.28876328]
#  ...
#  [23.93855259]
#  [35.94036768]
#  [28.43500877]]

# %%
#做ROC曲线
plt.figure()
plt.plot(range(len(y_pred[:100])),y_pred[:100],'b',label="predict")
plt.plot(range(len(y_pred[:100])),y_test[:100],'r',label="test")
plt.legend(loc="best") #显示图中的标签
plt.xlabel("the number of sales")
plt.ylabel('value of sales')
plt.show()

# %%
df2019 = pd.read_csv('D:/chargeorder/2019order_all.txt',encoding='utf-8',sep='\t')
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
station = pd.read_csv('D:/station_energy.txt',encoding='utf-8',sep='\t')

# %%
station.head(3)
# Out:
#    charge_energy
# 0           6.99
# 1          19.57
# 2           9.95

# %%
station.count()
# Out:
# charge_energy    51592
# dtype: int64

# %%
station_energy['charge_energy'].sum()
# Out:
# 2501228.03

# %%
station_energy = station_energy['charge_energy']
station_energy.plot();

# %%
station_energy[:500].plot()

# %%
station_energy[station_energy>80].count()
# Out:
# 9521

# %%
station_energy[station_energy<40].count()
# Out:
# 27510

# %%
df2019 = df2019.drop(index=[107904,108923,256156,256973,256983,257763,257772,290924,292291,328083,329018,390146,390596,392666,395376,395949,459403,487193,487202,700490,785690,911570,911612,911634,919904,928083,935412,935413,935415])

# %%
for i in range(1,6):
    df2019_01 = df2019[df2019['charge_start_month']==i]
    for j in range(1,32):
        df2019_01_01 = df2019_01[df2019_01['charge_start_day']==j]
        energy_2019 = int(df2019_01_01['charge_energy'].sum())
        with open('D:/energy_2019.txt',mode='a',encoding='utf-8',newline='\n') as f:
            f.writelines('2019/%s/%s'%(i,j)+ ',' + str(energy_2019)+ '\r\n')

# %%
energy_2019 = pd.read_csv('D:/energy_2019.txt',encoding='utf-8')
plt.figure(figsize=(20,12))
energy_2019.plot();
plt.xticks(np.arange(1,150,5));

# %%
energy_2018 = pd.read_csv('D:/energy_2018.txt',encoding='utf-8')

plt.figure(figsize=(32,20))
energy_2018.plot();
plt.xticks(np.arange(1,400,30));

# %%
df2018['charge_energy'].sum()
# Out:
# 61003590.37999996

# %%
#2018年每月充电量统计
for i in range(1,13):
#     df2018_ = ('df2018_' + '%d')%i
    df2018_ = df2018[df2018['charge_start_month']==i]
#     print('charge_energy month_%d:'%i,df2018_['charge_energy'].sum())
    print(df2018_['charge_energy'].sum())
# Out:
# 947729.33
# 1132635.18
# 1781133.64
# 2067881.9
# 3033604.0999999996
# 5198551.36
# 6824194.609999999
# 7298084.139999999
# 6976438.96
# 7329583.900000002
# 8501758.469999999
# 9697121.93

# %%
#2019年每月充电量统计
for i in range(1,6):
#     df2018_ = ('df2018_' + '%d')%i
    df2019_ = df2019[df2019['charge_start_month']==i]
    print(df2019_['charge_energy'].count())
# Out:
# 262216
# 219801
# 287268
# 286570
# 216865

# %%
energy_list = [909495,1081881,1720110,1997546,2899618,5199660,6596036,7049300,6729125,7070178,8197702,9699917,10258993,8908256,11450395,11547075, 8652757]

# %%
plt.plot(energy_list)
plt.xticks(np.arange(0,18,1));

# %%
month = list(range(1,18))

# %%
plt.scatter(month,energy_list)
plt.xticks(np.arange(0,18,1));

# %%
station = pd.read_csv('D:/station_id.txt',sep='\t')
station['charge_start_time'] = pd.to_datetime(station['charge_start_time'])
station['charge_start_time'] = station['charge_start_time'].dt.year

# %%
station.head(3)
# Out:
#    charge_start_time  charge_energy
# 0             2017.0           6.99
# 1             2017.0          19.57
# 2             2018.0           9.95

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation


def data_func(data_pro,sequence_length=10):
    data = []
    for i in range(len(data_pro) - sequence_length - 1):
        data.append(data_pro[i: i + sequence_length + 1])
    reshaped_data = np.array(data).astype('float64')

     #打乱第一维数据
#     np.random.shuffle(reshaped_data)
    X = reshaped_data[:, :-1]
    y = reshaped_data[:, -1]
    return X,y

def load_data(file_name,sequence_length=10,split=0.8):
    #提取energy这一列数据
    station_en = pd.read_csv(file_name,sep = '\t',usecols=[1])
    #将数据转换为数组
    station_en = np.array(station_en).astype(float)

    #80%作为训练数据
    split_boundary = int(station_en.shape[0] * split)
    train_X = station_en[: split_boundary]
    
    #数据预处理：数据归一化，缩放至0-1之间，
    scaler = MinMaxScaler()
    energy_all = scaler.fit_transform(station_en)
    
    train_X,train_y=data_func(energy_all,sequence_length=10)
    
    #20%作为测试数据
    test_X = station_en[split_boundary:]
    
    data_test = scaler.transform(test_X)
    test_X,test_y = data_func(data_test,sequence_length=10)
    
    return train_X,train_y,test_X,test_y,scaler
#     train_X = np.reshape(train_X,(train_X.shape[0],train_X.shape[1],1))
#     test_X = np.reshape(test_X,(test_X.shape[0],test_X.shape[1],1))

def build_model():
    model = Sequential()
    model.add(LSTM(input_dim=1,output_dim=50,return_sequences=True))
    model.add(LSTM(100,return_sequences=False))
    model.add(Dense(output_dim=1))
    model.add(Activation('linear'))
    
    model.compile(loss='mse', optimizer='rmsprop')
    return model


def train_model(train_X,train_y,test_X,test_y):
    model = build_model()
    try:
        model.fit(train_X,train_y,batch_size=512,nb_epoch=50,validation_split=0.1)
        predict = model.predict(test_X)
        predict = np.reshape(predict,(predict.size,))
    except KeyboardInterrupt:
        print(predict)
        print(test_y)
    print('predict:\n',predict)
    print('test_y:\n',test_y)
    #预测的散点值和真实值的散点值画图
    try:
        fig1 = plt.figure(1)
        plt.plot(predict,'r:')
        plt.plot(test_y,'g-')
        plt.legend(['predict','true'])
    except Exception as e:
        print(e)
    return predict,test_y

if __name__ == '__main__':
        # 加载数据
    train_X, train_y, test_X, test_y, scaler = load_data('D:/station_id.txt')    
    train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
    test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))
    # 模型训练  
    
    predict_y, test_y = train_model(train_X, train_y, test_X, test_y)
    # 对标准化处理后的数据还原
    predict_y = scaler.inverse_transform([[i] for i in predict_y])
    test_y = scaler.inverse_transform(test_y)
    # 把预测和真实数据对比
    fig2 = plt.figure(2)
    plt.plot(predict_y, 'g:')
    plt.plot(test_y, 'r-')
    plt.legend(['predict', 'true'])
    plt.show()
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\ipykernel_launcher.py:46: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
# D:\software\Anaconda-InstallFiles\lib\site-packages\ipykernel_launcher.py:46: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(return_sequences=True, input_shape=(None, 1), units=50)`
# D:\software\Anaconda-InstallFiles\lib\site-packages\ipykernel_launcher.py:48: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1)`
# D:\software\Anaconda-InstallFiles\lib\site-packages\ipykernel_launcher.py:58: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 46455 samples, validate on 5162 samples
# Epoch 1/50
# 46455/46455 [==============================] - 12s 248us/step - loss: 0.0119 - val_loss: 0.0166
# Epoch 2/50
# 46455/46455 [==============================] - 10s 221us/step - loss: 0.0115 - val_loss: 0.0171
# Epoch 3/50
# ...

# %%
###################

# %%
date1819 = pd.read_csv('D:/energy_day.txt',encoding='utf-8',index_col='charge_date')

#自相关图
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(date1819).show();
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
from statsmodels.tsa.stattools import adfuller as ADF
print('原始序列的ADF检验结果adf、pvalue、usedlag、nobs、critical values、icbest、regresults、resstore：',ADF(date1819))

# %%
#一阶差分后
diff_date1819 = date1819.diff()
diff_date1819.columns = ['charge_energy']
diff_date1819.plot()
plt.show()

# %%
#自相关图
plot_acf(diff_date1819).show()
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(diff_date1819).show()
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
from statsmodels.tsa.arima_model import ARIMA
pmax = int(len(diff_date1819)/10)
qmax = int(len(diff_date1819)/10)
bic_matrix = [] 
print(pmax,qmax)
# for p in range(pmax+1):
#     tmp = []
#     for q in range(qmax+1):
#         try:
#             tmp.append(ARIMA(date1819,(p,1,q)).fit().bic)
#         except:
#             tmp.append(None)
#         bic_matrix.append(tmp)
#         bic_matrix = pd.DataFrame(bic_matrix)
#         p,q = bic_matrix.stack().idxmin()
#         print('bic最小的p和q的值为：%s,%s'%(p,q))
# Out:
# 40 40

# %%
#持久化模型预测
series = pd.read_csv('D:/energy_day.txt',encoding='utf-8',header=0,parse_dates=[0],index_col=0)
series.plot()
plt.show()
values = pd.DataFrame(series.values)
dataframe = pd.concat([values.shift(1),values],axis=1)
dataframe.columns = ['t-1','t+1']
print(dataframe.head(3))
dataframe = dataframe[1:]

#划分训练集和测试集
X = dataframe.values
train_size = int(len(X)*0.65)
train,test = X[1:train_size],X[train_size:]
train_X,train_y,test_X,test_y = train[:,0],train[:1],train[:,0],train[:,1]
from sklearn.metrics import mean_squared_error
def model_persistence(x):
    return x

predictions = list()
for x in test_X:
    yhat = model_persistence(x)
    predictions.append(yhat)
test_score = mean_squared_error(test_y,predictions)
print('test mse:%.3f'%test_score)
# plot predictions and expected results
plt.plot(train_y)
plt.plot([None for i in train_y] + [x for x in test_y])
plt.plot([None for i in train_y] + [x for x in predictions])
plt.show()

# %%
std = pd.read_csv('D:/station0581.txt',encoding='utf-8',sep='\t',usecols=[0,2])
std.head(3)
# Out:
#    charge_energy charge_start_date
# 0           1.16         4-12-2018
# 1          20.51         7-12-2018
# 2          26.73          4-8-2016

# %%
std[std['charge_start_date']=='4-9-2016']['charge_energy'].sum()
# Out:
# 5521.290000000001

# %%
#每天充电量统计
year = [2016,2017,2018,2019]
for y in year:
    print(y)
    for m in range(1,13):
        for t in range(1,32):
            date = ('%s-%s-%s')%(t,m,y)
            std_en = std['charge_start_date']==date
            energy_day = int(std[std_en]['charge_energy'].sum())

            with open('D:/energy_day.txt',mode='a',encoding='utf-8',newline='\n') as f:
                if energy_day >0:
                    f.writelines('%s-%s-%s'%(y,m,t)+ ',' + str(energy_day)+ '\r\n')
# Out:
# 2016
# 2017
# 2018
# 2019

# %%
import datetime
energy_day = pd.read_csv('D:/pile.txt',encoding='utf-8',sep='\t', index_col='month',parse_dates=['month'])
print(energy_day.head(2))
energy_day['pile'].plot();
# Out:
#              pile
# month
# 2016-03-01  60023
# 2016-04-01  65109

# %%
# energy_day[energy_day['charge_energy']>23000].index
# Out:
# DatetimeIndex(['2017-04-06'], dtype='datetime64[ns]', name='charge_date', freq=None)

# %%
energy_day01 = energy_day['2018-06-01':]
energy_day01.plot();

# %%
train = energy_day[:'2019-03']
test = energy_day['2019-03':]

# %%
energy_day['pile01'] = energy_day['pile'].diff()
fig = plt.figure(figsize=(20,6))
ax1 = fig.add_subplot(131)
ax1.plot(energy_day['pile01']);

# energy_day01['charge_energy_1'] = energy_day01['charge_energy'].diff()
# energy_day01['charge_energy_2'] = energy_day01['charge_energy_1'].diff()
# fig = plt.figure(figsize=(20,6))
# ax1 = fig.add_subplot(131)
# ax1.plot(energy_day01['charge_energy']);
# ax2 = fig.add_subplot(132)
# ax2.plot(energy_day01['charge_energy_1']);
# ax3 = fig.add_subplot(133)
# ax3.plot(energy_day01['charge_energy_2']);

# %%
import statsmodels.api as sm
fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(train,lags=10,ax=ax1)
ax1.xaxis.set_ticks_position('bottom')
fig.tight_layout()

ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(train,lags=10,ax=ax2)
ax1.xaxis.set_ticks_position('bottom')
fig.tight_layout()

# %%
#计算p、q最优值
train_results = sm.tsa.arma_order_select_ic(train,ic=['aic','bic'],trend='nc', max_ar=5, max_ma=3)
print('AIC',train_results.aic_min_order)
print('BIC',train_results.bic_min_order)
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ...

# %%
model = sm.tsa.ARIMA(train, order=(2, 0, 0))
results = model.fit()
print(results.params)
resid = results.resid #赋值
fig = plt.figure(figsize=(28,3))
fig = sm.graphics.tsa.plot_acf(resid.values.squeeze(), lags=20)
plt.show()
# Out:
# const         196636.486192
# ar.L1.pile         1.646247
# ar.L2.pile        -0.646247
# dtype: float64
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\base\model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
model = sm.tsa.ARIMA(energy_day['pile'][1:], order=(2, 0, 0))
results = model.fit()
predict_sunspots = results.predict(start=str('2019-02'),end=str('2019-08'),dynamic=False)
# print(predict_sunspots)
fig, ax = plt.subplots(figsize=(12, 8))
ax = energy_day.plot(ax=ax)
predict_sunspots.plot(ax=ax);
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# D:\software\Anaconda-InstallFiles\lib\site-packages\statsmodels\tsa\base\tsa_model.py:336: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)

# %%
#预测下一个值
results.forecast()[1]
# Out:
# array([8234.01110019])

# %%
#均方根误差
from math import sqrt
from sklearn import metrics
from sklearn.metrics import mean_squared_error
rmse = sqrt(mean_squared_error(test,predict_sunspots))
mse = metrics.mean_squared_error(test,predict_sunspots)
print('mse的值为：',mse)
print('rmse的值为：',rmse)
# Out:
# mse的值为： 574367.083767348
# rmse的值为： 757.8700968948095

# %%
order2018 = pd.read_csv('D:/chargeorder/2018order.txt',sep='\t',encoding='utf-8')
# Out:
# D:\software\Anaconda-InstallFiles\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import pymysql
# 创建和数据库服务器的连接 服务器地址\端口\用户名\密码\数据库名\通信使用字符和数据库字符集一致
db = pymysql.connect(host='106.15.223.235', port=3306, user='readonly', password='abc123$%',database='renwochong', charset='utf8')
# 使用cursor()方法获取游标
cursor = db.cursor()
for i in range(1,6):
    # sql插入数据语句，注意是三引号
    sql = """select sum(charge_energy),sum(charge_total_fee) from qs_charge_order where
    station_id = 1134209819042827168 and
    charge_start_time >=20190%d01 and charge_start_time <=20190%d31 
    and charge_energy >=1"""%(i,i)
    #执行sql语句,对于操作数据库增删改查操作都要考虑到事务的完整性,即如果操作失败,必须要回滚
    try:
        #执行sql语句
        cursor.execute(sql) #这条代码才是执行的语句
        re = cursor.fetchall()
        #获取执行结果
        print(re)  #fetchall()是获取所有数据,fetchone()是获取一条数据
        with open('D:/month_energy.txt',mode='a',encoding='utf-8') as mf:
            mf.write(re + '\n')
    except:
          #出现异常,执行回滚 
          db.rollback()

#关闭游标和连接
# cursor.close()
# conn.close()
# Out:
# ((Decimal('1617.78'), Decimal('2102.85')),)
# ((Decimal('1960.62'), Decimal('2548.31')),)
# ((Decimal('429.83'), Decimal('558.68')),)
# ((None, None),)
# ((None, None),)

# %%
from statsmodels.tsa.stattools import adfuller
from pandas import Series
from math import sqrt

# 创建差分化函数
def difference(dataset):
    diff = list()
    for i in range(1, len(dataset)):
        value = dataset[i] - dataset[i - 1]
        diff.append(value)
    return Series(diff)
 
series = Series.from_csv('D:/water.csv')
X = series.values
X = X.astype('float32')
# 差分化数据
stationary = difference(X)
stationary.index = series.index[1:]
# 检查时序是否已经变得平稳
result = adfuller(stationary)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# 绘制平稳时序的图
stationary.plot()
# 保存
stationary.to_csv('D:/stationary.csv')
# Out:
# ADF Statistic: -6.693248
# p-value: 0.000000
# Critical Values:
# 	1%: -3.519
# 	5%: -2.900
# 	10%: -2.587
# D:\software\Anaconda-InstallFiles\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
series = Series.from_csv('D:/water.csv', header=0)
split_point = len(series) - 10
dataset, validation = series[0:split_point], series[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('D:/dataset.csv')
validation.to_csv('D:/validation.csv')
# Out:
# Dataset 68, Validation 10
# D:\software\Anaconda-InstallFiles\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """
# D:\software\Anaconda-InstallFiles\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

series = Series.from_csv('D:/dataset.csv')
plt.figure(figsize=(12,8))
plt.subplot(211)
plot_acf(series,ax=plt.gca())
plt.subplot(212)
plot_pacf(series,ax=plt.gca())
plt.show()

# %%
import warnings

# 基于给定的ARIMA(p,d,q)值评评估该模型并返回RMSE值
def evaluate_arima_model(X, arima_order):
    # 准备训练集数据
    X = X.astype('float32')
    train_size = int(len(X) * 0.50)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
    # 作出预测
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
#         model_fit = model.fit(disp=0)
        model_fit = model.fit(trend='nc', disp=0)
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
    # 计算测试集上的预测误差
    mse = mean_squared_error(test, predictions)
    rmse = sqrt(mse)
    return rmse
 
# 评估带有不同参数值的每个ARIMA模型
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    mse = evaluate_arima_model(dataset, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                    print('ARIMA%s RMSE=%.3f' % (order,mse))
                except:
                    continue
        print('Best ARIMA:%s, RMSE=%.3f' % (best_cfg, best_score))
 
# 加载数据
series = Series.from_csv('D:/dataset.csv')
# 评价参数
p_values = range(0, 6)
d_values = range(0, 2)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# Best ARIMA:None, RMSE=inf
# Best ARIMA:None, RMSE=inf
# Best ARIMA:None, RMSE=inf
# Best ARIMA:None, RMSE=inf
# Best ARIMA:None, RMSE=inf
# Best ARIMA:None, RMSE=inf

# %%
import pymysql
# 创建和数据库服务器的连接 服务器地址\端口\用户名\密码\数据库名\通信使用字符和数据库字符集一致
db = pymysql.connect(host='47.103.80.208', port=3306, user='readonly', password='readonly@2019',database='chargerlink_charger', charset='utf8')
# 使用cursor()方法获取游标
cursor = db.cursor()
for i in range(10,27):
    # sql插入数据语句，注意是三引号
    sql = """select elec_price,actual_price,order_electricity from t_charger_order where create_time >= 201906%d and create_time <= 201906%d and order_price > 0;"""%(i,i+1)
    #执行sql语句,对于操作数据库增删改查操作都要考虑到事务的完整性,即如果操作失败,必须要回滚
    try:
        #执行sql语句
        cursor.execute(sql) #这条代码才是执行的语句
        re = cursor.fetchall()
        #获取执行结果
        print('201906',i,re)  #fetchall()是获取所有数据,fetchone()是获取一条数据
        with open('D:/order_num.txt',mode='a',encoding='utf-8') as mf:
            mf.write('201906' + i + ','+ re + '\n')
    except:
          #出现异常,执行回滚 
          db.rollback()

#关闭游标和连接
# cursor.close()
# db.close()
# Out:
# 201906 10 ((494, 860, 1830), (352, 612, 1302), (939, 1634, 3477), (333, 579, 1232), (991, 1725, 3672), (1075, 1871, 3980), (1033, 1798, 3826), (11, 13, 10), (10, 13, 13), (3036, 3805, 3843), (2012, 2495, 2415), (2549, 3078, 2643), (35, 53, 35), (1162, 1432, 1353), (23, 38, 29), (3, 5, 3), (3021, 3575, 2772), (1, 2, 1), (1797, 2125, 1649), (391, 463, 359), (2, 4, 4), (1185, 1485, 1500), (552, 692, 699), (580, 955, 1876), (413, 718, 1528), (761, 1324, 2817), (400, 696, 1482), (839, 1460, 3107), (859, 1496, 3182))
# 201906 11 ((875, 1523, 3241), (665, 1157, 2462), (797, 1388, 2953), (1076, 1873, 3984), (984, 1712, 3643), (614, 1069, 2274), (2558, 3172, 3071), (1530, 1917, 1937), (2063, 2585, 2611), (2118, 2645, 2635), (743, 931, 941), (1142, 1431, 1446), (2274, 2850, 2878), (1310, 1558, 1237), (165, 195, 151), (3643, 4311, 3342), (3102, 3671, 2846), (192, 227, 176), (2554, 3023, 2343), (29, 36, 37), (1641, 2056, 2077), (848, 1476, 3139), (1087, 1892, 4026), (1086, 1891, 4025))
# ...
